# %% [markdown]
# # Salience Maps
# - for Epistemic, Aleatoric, and Predictive Uncertainty

# %%
# %matplotlib inline
from visualisation_functions import *
# Out:
# /remote/mlsalt-2017/lrc45/Envs/concretedropout/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ### Plot epistemic/aleatoric for images with low softmax

# %%
idx = [150, 5518, 5504, 4442, 6326]
plot_epistemic_aleatoric(idx, 'cifar10-low-softmax-ep-al.png')

# %%
plot_across_runs(150, 'cifar10-{}-across-runs.png'.format(150))

# %% [markdown]
# ### Absolute magnitudes of salience (for the appendix)

# %%
plot_epistemic_aleatoric_appendix(idx, 'cifar10-low-softmax-ep-al.png')

# %% [markdown]
# ### Plot predictive uncertainty vs. predictive difference, same images

# %%
plot_predictive_difference(idx, 'cifar10-low-softmax-pred-diff.png')

# %% [markdown]
# ### Uncertainty maps for high softmax images

# %%
ind_high = [3101, 3717, 4663, 9814, 8150]
plot_epistemic_aleatoric(ind_high, 'cifar10-high-softmax-ep-al.png')

# %% [markdown]
# ### High softmax images, appendix figure

# %%
plot_epistemic_aleatoric_appendix(ind_high, 'cifar10-high-softmax-ep-al.png')

# %% [markdown]
# ### Salience maps as more training data is added

# %%
# # 150, 5518, 5504, 4442, 6326 low softmax
# # 3101, 3717, 4663, 9814, 8150 high softmax
plot_training_n(150, 'cifar10-{}-training-n.png'.format(150))

# %%
plot_training_n(4663)
